# %%
import torch
import torch_geometric
print(torch.__version__)
# Out:
# 1.12.1

# %%
from torch_geometric.datasets import KarateClub
from torch_geometric.transforms import NormalizeFeatures

dataset = KarateClub()

print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('===========================================================================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Dataset: KarateClub():
# ======================
# Number of graphs: 1
# Number of features: 34
# Number of classes: 4
#
# Data(x=[34, 34], edge_index=[2, 156], y=[34], train_mask=[34])
# ===========================================================================================================
# Number of nodes: 34
# Number of edges: 156
# Average node degree: 4.59
# Number of training nodes: 4
# Training node label rate: 0.12
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True

# %%
from torch_geometric.nn import GCNConv
import torch.nn.functional as F

class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        torch.manual_seed(123)
        self.conv1 = GCNConv(dataset.num_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes)
        
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training = self.training)
        x = self.conv2(x, edge_index)
        return x
model = GCN(hidden_channels=16)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(34, 16)
#   (conv2): GCNConv(16, 4)
# )

# %%
model = GCN(hidden_channels=16)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
loss_function = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    optimizer.zero_grad() # Clear gradients
    out = model(data.x, data.edge_index)
    loss = loss_function(out[data.train_mask], data.y[data.train_mask]) # Compute the loss solely based on the training nodes.
    loss.backward() # Derive gradients
    optimizer.step()
    return loss

def test():
    model.eval()
    out = model(data.x, data.edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability
    test_correct = pred[data.test_mask] == data.y[data.test_mask] # Check against ground-truth labels.
    test_acc = int(test_correct.sum()) / int(data.test_mask.sum()) # Derive ratio of correct predictions.
    return test_acc

for epoch in range(1, 101):
    loss = train()
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
# Out:
# Epoch: 001, Loss: 1.3794
# Epoch: 002, Loss: 1.3632
# Epoch: 003, Loss: 1.3887
# Epoch: 004, Loss: 1.3453
# Epoch: 005, Loss: 1.3073
# Epoch: 006, Loss: 1.2995
# Epoch: 007, Loss: 1.2613
# Epoch: 008, Loss: 1.2527
# Epoch: 009, Loss: 1.2884
# Epoch: 010, Loss: 1.2608
# Epoch: 011, Loss: 1.1862
# Epoch: 012, Loss: 1.1579
# Epoch: 013, Loss: 1.1463
# Epoch: 014, Loss: 1.0797
# Epoch: 015, Loss: 1.1226
# Epoch: 016, Loss: 1.1151
# Epoch: 017, Loss: 1.0599
# Epoch: 018, Loss: 1.0321
# Epoch: 019, Loss: 0.9861
# Epoch: 020, Loss: 0.9460
# Epoch: 021, Loss: 0.9907
# Epoch: 022, Loss: 0.9093
# Epoch: 023, Loss: 0.8629
# Epoch: 024, Loss: 0.8950
# Epoch: 025, Loss: 0.8466
# Epoch: 026, Loss: 0.8092
# Epoch: 027, Loss: 0.7951
# Epoch: 028, Loss: 0.6787
# Epoch: 029, Loss: 0.7002
# Epoch: 030, Loss: 0.6985
# Epoch: 031, Loss: 0.7876
# Epoch: 032, Loss: 0.7004
# Epoch: 033, Loss: 0.6861
# Epoch: 034, Loss: 0.6180
# Epoch: 035, Loss: 0.6041
# Epoch: 036, Loss: 0.6322
# Epoch: 037, Loss: 0.5697
# Epoch: 038, Loss: 0.6257
# Epoch: 039, Loss: 0.5527
# Epoch: 040, Loss: 0.4534
# Epoch: 041, Loss: 0.4572
# Epoch: 042, Loss: 0.5207
# Epoch: 043, Loss: 0.4363
# Epoch: 044, Loss: 0.3103
# Epoch: 045, Loss: 0.3931
# Epoch: 046, Loss: 0.5074
# Epoch: 047, Loss: 0.3739
# Epoch: 048, Loss: 0.3958
# Epoch: 049, Loss: 0.2891
# Epoch: 050, Loss: 0.2756
# Epoch: 051, Loss: 0.2907
# Epoch: 052, Loss: 0.3135
# Epoch: 053, Loss: 0.3160
# Epoch: 054, Loss: 0.2435
# Epoch: 055, Loss: 0.2535
# Epoch: 056, Loss: 0.3190
# Epoch: 057, Loss: 0.2652
# Epoch: 058, Loss: 0.4061
# Epoch: 059, Loss: 0.2465
# Epoch: 060, Loss: 0.2342
# Epoch: 061, Loss: 0.3415
# Epoch: 062, Loss: 0.2142
# Epoch: 063, Loss: 0.2014
# Epoch: 064, Loss: 0.1416
# Epoch: 065, Loss: 0.2774
# Epoch: 066, Loss: 0.2796
# Epoch: 067, Loss: 0.3458
# Epoch: 068, Loss: 0.2497
# Epoch: 069, Loss: 0.3309
# Epoch: 070, Loss: 0.1484
# Epoch: 071, Loss: 0.1100
# Epoch: 072, Loss: 0.1427
# Epoch: 073, Loss: 0.1205
# Epoch: 074, Loss: 0.1711
# Epoch: 075, Loss: 0.1629
# Epoch: 076, Loss: 0.1301
# Epoch: 077, Loss: 0.0966
# Epoch: 078, Loss: 0.1357
# Epoch: 079, Loss: 0.1648
# Epoch: 080, Loss: 0.1595
# Epoch: 081, Loss: 0.0946
# Epoch: 082, Loss: 0.0627
# Epoch: 083, Loss: 0.1118
# Epoch: 084, Loss: 0.0957
# Epoch: 085, Loss: 0.0442
# Epoch: 086, Loss: 0.0460
# Epoch: 087, Loss: 0.1013
# Epoch: 088, Loss: 0.0787
# Epoch: 089, Loss: 0.1238
# Epoch: 090, Loss: 0.0535
# Epoch: 091, Loss: 0.0687
# Epoch: 092, Loss: 0.1096
# Epoch: 093, Loss: 0.0695
# Epoch: 094, Loss: 0.0672
# Epoch: 095, Loss: 0.0615
# Epoch: 096, Loss: 0.0413
# Epoch: 097, Loss: 0.0663
# Epoch: 098, Loss: 0.0370
# Epoch: 099, Loss: 0.1158
# Epoch: 100, Loss: 0.1696
